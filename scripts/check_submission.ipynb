# %%
import pandas as pd

# %%
sub = pd.read_csv("../resources/submission_v2.0.csv")

# %%
print(f"概率 > 0.5: {(sub['isFraud'] > 0.5).sum()}")
print(f"概率 <= 0.5: {(sub['isFraud'] <= 0.5).sum()}")
# Out:
# 概率 > 0.5: 8166
# 概率 <= 0.5: 498525
